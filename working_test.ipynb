# %%
import torch
from torch.utils.data import DataLoader, TensorDataset
import torch.nn.functional as F
from torch import nn
import os
from tqdm import tqdm

from model import DisentangledTripleVAE  # your model file

# ==========================================================
# CONFIG
# ==========================================================
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
BATCH_SIZE = 64
EPOCHS = 50
LR = 1e-3
LATENT_DIM = 16
HIDDEN_DIM = 128
SEQ_LEN_METEO = 365  # sequence length for decoder output
SEQ_LEN_PRIX = 5 # sequence length for decoder output
# Input dims
INPUT_DIM_CNN = 5  # e.g., meteo features
INPUT_DIM_RNN = 5   # e.g., price features
INPUT_DIM_MLP = 8   # e.g., soil vector
OUTPUT_DIM_DECODER = 8  # same as MLP decoder output

CHECKPOINT_DIR = "./checkpoints"
os.makedirs(CHECKPOINT_DIR, exist_ok=True)

# ==========================================================
# DUMMY DATASET (replace with your real data)
# ==========================================================
# xA: [B, seq_len, F_cnn], xB: [B, seq_len, F_rnn], xC: [B, F_mlp]
num_samples = 1000
xA = torch.randn(num_samples, SEQ_LEN_METEO, INPUT_DIM_CNN)
xB = torch.randn(num_samples, SEQ_LEN_PRIX, INPUT_DIM_RNN)
xC = torch.randn(num_samples, INPUT_DIM_MLP)

dataset = TensorDataset(xA, xB, xC)

# %%
dataset_loader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)

# %%
it = iter(dataset_loader)
first = next(it)

# %%
a, b, c = first

# %%
a.shape, b.shape, c.shape
# Out:
# (torch.Size([64, 365, 5]), torch.Size([64, 5, 5]), torch.Size([64, 8]))
